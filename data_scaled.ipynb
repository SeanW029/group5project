# %%
from path import Path
import pandas as pd

# %%
data = Path('clean_df.csv')
df = pd.read_csv(data)
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5547906ac6b6> in <module>
#       1 data = Path('clean_df.csv')
# ----> 2 df = pd.read_csv(data)
#       3 df.head(20)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
df['Month'] = pd.DatetimeIndex(df['closing_date']).month

# %%
df = df.drop(['closing_date'], axis = 1)

# %%
df.head(10)
# Out:
#            id    price  bedrooms  bathrooms  home_size  lot_size  floors  \
# 0  7129300520   221900         3       1.00       1180      5650     1.0
# 1  6414100192   538000         3       2.25       2570      7242     2.0
# 2  5631500400   180000         2       1.00        770     10000     1.0
# 3  2487200875   604000         4       3.00       1960      5000     1.0
# 4  1954400510   510000         3       2.00       1680      8080     1.0
# 5  7237550310  1225000         4       4.50       5420    101930     1.0
# 6  1321400060   257500         3       2.25       1715      6819     2.0
# 7  2008000270   291850         3       1.50       1060      9711     1.0
# 8  2414600126   229500         3       1.00       1780      7470     1.0
# 9  3793500160   323000         3       2.50       1890      6560     2.0
#
#    waterfront  view  condition  ...  above_size  basement_size  year  \
# 0           0     0          3  ...        1180              0  1955
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'home_size',
#  'lot_size',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'above_size',
#  'basement_size',
#  'year',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'homereno_2015',
#  'lotreno_2015',
#  'Month']

# %%
col_order = ['id','price','Month','bedrooms','bathrooms','home_size','lot_size','floors','waterfront','view','condition','grade','above_size','basement_size','year','yr_renovated','zipcode','lat','long','homereno_2015','lotreno_2015']

# %%
df = df[col_order]

# %%
df.head(10)
# Out:
#            id    price  Month  bedrooms  bathrooms  home_size  lot_size  \
# 0  7129300520   221900     10         3       1.00       1180      5650
# 1  6414100192   538000     12         3       2.25       2570      7242
# 2  5631500400   180000      2         2       1.00        770     10000
# 3  2487200875   604000     12         4       3.00       1960      5000
# 4  1954400510   510000      2         3       2.00       1680      8080
# 5  7237550310  1225000      5         4       4.50       5420    101930
# 6  1321400060   257500      6         3       2.25       1715      6819
# 7  2008000270   291850      1         3       1.50       1060      9711
# 8  2414600126   229500      4         3       1.00       1780      7470
# 9  3793500160   323000      3         3       2.50       1890      6560
#
#    floors  waterfront  view  ...  grade  above_size  basement_size  year  \
# 0     1.0           0     0  ...      7        1180              0  1955
# ...

# %%
from sklearn.preprocessing import StandardScaler
data_scaler = StandardScaler()

# %%
df_scaled = data_scaler.fit_transform(df)

# %%
df_scaled
# Out:
# array([[ 0.88614631, -0.86671733,  1.09962055, ..., -0.30607896,
#         -0.9433552 , -0.26071541],
#        [ 0.63751062, -0.00568792,  1.74162654, ..., -0.74634143,
#         -0.43268619, -0.18786773],
#        [ 0.36544385, -0.98084935, -1.46840343, ..., -0.13565477,
#          1.07013975, -0.17237524],
#        ...,
#        [-1.06275071, -0.37586519, -0.18439144, ..., -0.60432128,
#         -1.41025258, -0.39414129],
#        [-1.49104567, -0.38158814, -1.78940643, ...,  1.02891048,
#         -0.8412214 , -0.42051149],
#        [-1.0627507 , -0.58588173,  1.09962055, ..., -0.60432128,
#         -1.41025258, -0.41794772]])

# %%
df_scaled.shape
# Out:
# (21613, 21)

# %%
df_scaled[:5]
# Out:
# array([[ 0.88614631, -0.86671733,  1.09962055, -0.39873715, -1.44746357,
#         -0.97983502, -0.22832133, -0.915427  , -0.08717263, -0.30575946,
#         -0.62918687, -0.55883575, -0.73470764, -0.65868104, -0.54489777,
#         -0.21012839,  1.87015159, -0.35257175, -0.30607896, -0.9433552 ,
#         -0.26071541],
#        [ 0.63751062, -0.00568792,  1.74162654, -0.39873715,  0.1756067 ,
#          0.53363434, -0.18988538,  0.93650577, -0.08717263, -0.30575946,
#         -0.62918687, -0.55883575,  0.46084084,  0.2451414 , -0.6810785 ,
#          4.7466776 ,  0.87956753,  1.16156823, -0.74634143, -0.43268619,
#         -0.18786773],
#        [ 0.36544385, -0.98084935, -1.46840343, -1.47395936, -1.44746357,
#         -1.42625404, -0.12329847, -0.915427  , -0.08717263, -0.30575946,
#         -0.62918687, -1.40958711, -1.22983377, -0.65868104, -1.29389179,
#         -0.21012839, -0.9333882 ,  1.28353661, -0.13565477,  1.07013975,
#         -0.17237524],
# ...

# %%
df.to_csv("data_scaled.csv", index=False, header=True)
