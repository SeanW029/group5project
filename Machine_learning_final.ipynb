# %%
from path import Path
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
import seaborn as sns 
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
data = Path('resources\kc_house_data.csv')
df = pd.read_csv(data)
df.head(20)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# 11  9212900260  20140527T000000   468000.0         2       1.00         1160
# 12   114101516  20140528T000000   310000.0         3       1.00         1430
# 13  6054650070  20141007T000000   400000.0         3       1.75         1370
# 14  1175000570  20150312T000000   530000.0         5       2.00         1810
# 15  9297300055  20150124T000000   650000.0         4       3.00         2950
# 16  1875500060  20140731T000000   395000.0         3       2.00         1890
# 17  6865200140  20140529T000000   485000.0         4       1.00         1600
# 18    16000397  20141205T000000   189000.0         2       1.00         1200
# 19  7983200060  20150424T000000   230000.0         3       1.00         1250
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0       5650     1.0           0     0  ...      7        1180              0
# 1       7242     2.0           0     0  ...      7        2170            400
# 2      10000     1.0           0     0  ...      6         770              0
# 3       5000     1.0           0     0  ...      7        1050            910
# 4       8080     1.0           0     0  ...      8        1680              0
# 5     101930     1.0           0     0  ...     11        3890           1530
# 6       6819     2.0           0     0  ...      7        1715              0
# 7       9711     1.0           0     0  ...      7        1060              0
# 8       7470     1.0           0     0  ...      7        1050            730
# 9       6560     2.0           0     0  ...      7        1890              0
# 10      9796     1.0           0     0  ...      8        1860           1700
# 11      6000     1.0           0     0  ...      7         860            300
# 12     19901     1.5           0     0  ...      7        1430              0
# 13      9680     1.0           0     0  ...      7        1370              0
# 14      4850     1.5           0     0  ...      7        1810              0
# 15      5000     2.0           0     3  ...      9        1980            970
# 16     14040     2.0           0     0  ...      7        1890              0
# 17      4300     1.5           0     0  ...      7        1600              0
# 18      9850     1.0           0     0  ...      7        1200              0
# 19      9774     1.0           0     0  ...      7        1250              0
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0       1955             0    98178  47.5112 -122.257           1340
# 1       1951          1991    98125  47.7210 -122.319           1690
# 2       1933             0    98028  47.7379 -122.233           2720
# 3       1965             0    98136  47.5208 -122.393           1360
# 4       1987             0    98074  47.6168 -122.045           1800
# 5       2001             0    98053  47.6561 -122.005           4760
# 6       1995             0    98003  47.3097 -122.327           2238
# 7       1963             0    98198  47.4095 -122.315           1650
# 8       1960             0    98146  47.5123 -122.337           1780
# 9       2003             0    98038  47.3684 -122.031           2390
# 10      1965             0    98007  47.6007 -122.145           2210
# 11      1942             0    98115  47.6900 -122.292           1330
# 12      1927             0    98028  47.7558 -122.229           1780
# 13      1977             0    98074  47.6127 -122.045           1370
# 14      1900             0    98107  47.6700 -122.394           1360
# 15      1979             0    98126  47.5714 -122.375           2140
# 16      1994             0    98019  47.7277 -121.962           1890
# 17      1916             0    98103  47.6648 -122.343           1610
# 18      1921             0    98002  47.3089 -122.210           1060
# 19      1969             0    98003  47.3343 -122.306           1280
#
#     sqft_lot15
# 0         5650
# 1         7639
# 2         8062
# 3         5000
# 4         7503
# 5       101930
# 6         6819
# 7         9711
# 8         8113
# 9         7570
# 10        8925
# 11        6000
# 12       12697
# 13       10208
# 14        4850
# 15        4000
# 16       14018
# 17        4300
# 18        5095
# 19        8850
#
# [20 rows x 21 columns]

# %%
df['Month'] = pd.DatetimeIndex(df['date']).month

# %%
df = df.drop(['date'], axis = 1)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15',
#  'Month']

# %%
col_order = ['id','Month','price','bedrooms','bathrooms','sqft_living',
            'sqft_lot','floors','waterfront','view','condition','grade','sqft_above','sqft_basement','yr_built',
             'yr_renovated','zipcode','lat','long','sqft_living15','sqft_lot15']

# %%
df = df[col_order]

# %%
df.head(10)
# Out:
#            id  Month      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520     10   221900.0         3       1.00         1180      5650
# 1  6414100192     12   538000.0         3       2.25         2570      7242
# 2  5631500400      2   180000.0         2       1.00          770     10000
# 3  2487200875     12   604000.0         4       3.00         1960      5000
# 4  1954400510      2   510000.0         3       2.00         1680      8080
# 5  7237550310      5  1225000.0         4       4.50         5420    101930
# 6  1321400060      6   257500.0         3       2.25         1715      6819
# 7  2008000270      1   291850.0         3       1.50         1060      9711
# 8  2414600126      4   229500.0         3       1.00         1780      7470
# 9  3793500160      3   323000.0         3       2.50         1890      6560
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
# 5     1.0           0     0  ...     11        3890           1530      2001
# 6     2.0           0     0  ...      7        1715              0      1995
# 7     1.0           0     0  ...      7        1060              0      1963
# 8     1.0           0     0  ...      7        1050            730      1960
# 9     2.0           0     0  ...      7        1890              0      2003
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
# 5             0    98053  47.6561 -122.005           4760      101930
# 6             0    98003  47.3097 -122.327           2238        6819
# 7             0    98198  47.4095 -122.315           1650        9711
# 8             0    98146  47.5123 -122.337           1780        8113
# 9             0    98038  47.3684 -122.031           2390        7570
#
# [10 rows x 21 columns]

# %%
# Creating X
X = df.drop(['price'], axis = 1)
X.head()
# Out:
#            id  Month  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520     10         3       1.00         1180      5650     1.0
# 1  6414100192     12         3       2.25         2570      7242     2.0
# 2  5631500400      2         2       1.00          770     10000     1.0
# 3  2487200875     12         4       3.00         1960      5000     1.0
# 4  1954400510      2         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
# Creating y
y = df["price"]
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
# data = Path('Resources/kc_house_data.csv')
# df = pd.read_csv(data).set_index("id" )
# df.head(20)

# %%
# df['date'] = pd.to_datetime(df['date']) #Dropping date column bcz i won't gonna day and month and creating new year column
# df['year'] = df['date'].dt.year
# df = df.drop("date",axis=1)
# df

# %%
# X = df.drop(['date', 'price', 'zipcode', 'lat', 'long'], axis = 1)
# X = df.drop(['price'], axis = 1)

# %%
# y = df["price"]
# X = df.drop(columns="price")

# %%
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
X.head()
# Out:
#            id  Month  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520     10         3       1.00         1180      5650     1.0
# 1  6414100192     12         3       2.25         2570      7242     2.0
# 2  5631500400      2         2       1.00          770     10000     1.0
# 3  2487200875     12         4       3.00         1960      5000     1.0
# 4  1954400510      2         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
import statsmodels.api as sm

# %%
mod = sm.OLS(y, X)

# %%
res = mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2805.
# Date:                Tue, 16 Nov 2021   Prob (F-statistic):               0.00
# Time:                        21:09:57   Log-Likelihood:            -2.9458e+05
# No. Observations:               21613   AIC:                         5.892e+05
# Df Residuals:                   21594   BIC:                         5.893e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# id            -1.286e-06   4.82e-07     -2.670      0.008   -2.23e-06   -3.42e-07
# Month         -3062.2079    439.371     -6.970      0.000   -3923.407   -2201.009
# bedrooms      -3.565e+04   1886.517    -18.897      0.000   -3.93e+04    -3.2e+04
# bathrooms      4.099e+04   3249.768     12.612      0.000    3.46e+04    4.74e+04
# sqft_living     110.4312      2.266     48.734      0.000     105.990     114.873
# sqft_lot          0.1247      0.048      2.604      0.009       0.031       0.219
# floors         5656.4606   3537.398      1.599      0.110   -1277.100    1.26e+04
# waterfront     5.842e+05   1.73e+04     33.688      0.000     5.5e+05    6.18e+05
# view           5.228e+04   2126.554     24.583      0.000    4.81e+04    5.64e+04
# condition      2.752e+04   2321.986     11.851      0.000     2.3e+04    3.21e+04
# grade          9.556e+04   2143.185     44.587      0.000    9.14e+04    9.98e+04
# sqft_above       71.4091      2.235     31.946      0.000      67.028      75.790
# sqft_basement    39.0221      2.621     14.888      0.000      33.885      44.160
# yr_built      -2561.6017     67.922    -37.714      0.000   -2694.734   -2428.469
# yr_renovated     20.5898      3.642      5.653      0.000      13.450      27.729
# zipcode        -517.8763     17.830    -29.046      0.000    -552.824    -482.929
# lat            6.027e+05   1.07e+04     56.217      0.000    5.82e+05    6.24e+05
# long          -2.169e+05   1.31e+04    -16.605      0.000   -2.43e+05   -1.91e+05
# sqft_living15    22.9867      3.387      6.786      0.000      16.347      29.626
# sqft_lot15       -0.3855      0.073     -5.259      0.000      -0.529      -0.242
# ==============================================================================
# Omnibus:                    18454.762   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1907858.671
# Skew:                           3.583   Prob(JB):                         0.00
# Kurtosis:                      48.467   Cond. No.                     1.74e+22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.09e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape
# Out:
# (16209, 20)

# %%
# MAchine lerning model Linear Regression.
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression().fit(X_train, y_train)

# %%
y_pred = linear_reg.predict(X_test)
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test})
results.head(5)
# Out:
#          Prediction     Actual
# 735    4.525207e+05   365000.0
# 2830   7.410871e+05   865000.0
# 4106   1.230364e+06  1038000.0
# 16218  1.665828e+06  1490000.0
# 19964  7.269566e+05   711000.0

# %%
cross_val_score(linear_reg, X, y, cv=10)
# Out:
# array([0.6955615 , 0.69899595, 0.68927195, 0.6926956 , 0.68035148,
#        0.70561594, 0.71323353, 0.71040972, 0.69936734, 0.67369246])

# %%
# Linear Regression score
linear_reg.score(X, y, sample_weight=None)
# Out:
# 0.7003446845355261

# %%
# Machinbe learning model Random Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor(random_state=79)

# %%
# Machinbe learning model Random tree
y_pred = regressor.fit(X_train, y_train).predict(X_test)
results_tree = pd.DataFrame({"Prediction": y_pred, "Actual": y_test})
results_tree.head(5)
# Out:
#        Prediction     Actual
# 735      385000.0   365000.0
# 2830     825000.0   865000.0
# 4106    1225000.0  1038000.0
# 16218   1699000.0  1490000.0
# 19964    769000.0   711000.0

# %%
cross_val_score(regressor, X, y, cv=10)
# Out:
# array([0.81759649, 0.78681602, 0.76128754, 0.76092808, 0.6734723 ,
#        0.64395646, 0.75322446, 0.76112512, 0.72789787, 0.80135755])

# %%
# Tree score
regressor.score(X, y, sample_weight=None)
# Out:
# 0.9212965521318995

# %%
# Machinbe learning model Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor_forest = RandomForestRegressor(max_depth=2, random_state=79)

# %%
y_pred = regressor_forest.fit(X_train, y_train).predict(X_test)
results_forest = pd.DataFrame({"Prediction": y_pred, "Actual": y_test})
results_forest.head(5)
# Out:
#          Prediction     Actual
# 735    3.155011e+05   365000.0
# 2830   5.308580e+05   865000.0
# 4106   9.123269e+05  1038000.0
# 16218  1.421313e+06  1490000.0
# 19964  8.094779e+05   711000.0

# %%
cross_val_score(regressor_forest, X, y, cv=10)
# Out:
# array([0.51834514, 0.53612901, 0.55970558, 0.49169129, 0.51062762,
#        0.54908181, 0.56218064, 0.55970309, 0.55793741, 0.51878254])

# %%
# Forest score
regressor_forest.score(X, y, sample_weight=None)
# Out:
# 0.5362334751238881
